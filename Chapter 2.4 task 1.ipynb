# %%
filename = 'dataset_24465_4(3).txt'

# %%
with open(filename) as f:
    data = f.readlines()

# %%
data.reverse()

# %%
data
# Out:
# ['otvmhact\n',
#  'wtertwpklf\n',
#  'jtjqmzt\n',
#  'p\n',
#  'upx\n',
#  'bruche\n',
#  'wxw\n',
#  'jbsggstakm\n',
#  'pigczky\n',
#  'it\n',
#  'pwq\n',
#  'atqpw\n',
#  'luhwcmu\n',
#  'lmbwkytjrp\n',
#  'lzq\n',
#  'dn\n',
#  'yawd\n',
#  'noljcqqdwa\n',
#  'c\n',
#  'hpmmpcc\n',
#  'rfaxpyunlf\n',
#  'ivtnjrhqw\n',
#  'apb\n',
#  'i\n',
#  'vim\n',
#  'hsnxgbilyb\n',
#  'olxwbcqcdt\n',
#  'vlfayrknuo\n',
#  'v\n',
#  'iwvmyvh\n',
#  'huzzhwz\n',
#  'dxnqd\n',
#  'upltvezlin\n',
#  'rg\n',
#  'pvgrwhbf\n',
#  'xjqzwocq\n',
#  'aq\n',
#  'spmh\n',
#  'tydlypprv\n',
#  'flqzm\n',
#  'hfuawnya\n',
#  'os\n',
#  'czbd\n',
#  'jjnafejlb\n',
#  'k\n',
#  'fwipmsksj\n',
#  'arxya\n',
#  'pabe\n',
#  'eb\n',
#  'ibbkem\n',
#  'ubr\n',
#  'xq\n',
#  'yvsmrkwv\n',
#  'jtxgs\n',
#  'r\n',
#  'xxvfel\n',
#  'a\n',
#  'jrmghth\n',
#  'gvsaalc\n',
#  'yup\n',
#  'hguqmhhja\n',
#  'lcsdgcpxy\n',
#  'gycitldu\n',
#  'lzmwpu\n',
#  'jndod\n',
#  'vz\n',
#  's\n',
#  'tux\n',
#  'bcsthvndo\n',
# ...

# %%
tfile = open('t.txt', 'r+')

# %%
for i in range(len(data)):
    print(data[i])
    tfile.write(data[i])
# Out:
# otvmhact
#
# wtertwpklf
#
# jtjqmzt
#
# p
#
# upx
#
# bruche
#
# wxw
#
# jbsggstakm
#
# pigczky
#
# it
#
# pwq
#
# atqpw
#
# luhwcmu
#
# lmbwkytjrp
#
# lzq
#
# dn
#
# yawd
#
# noljcqqdwa
#
# c
#
# hpmmpcc
#
# rfaxpyunlf
#
# ivtnjrhqw
#
# apb
#
# i
#
# vim
#
# hsnxgbilyb
#
# olxwbcqcdt
#
# vlfayrknuo
#
# v
#
# iwvmyvh
#
# huzzhwz
#
# dxnqd
#
# upltvezlin
#
# rg
#
# pvgrwhbf
#
# xjqzwocq
#
# aq
#
# spmh
#
# tydlypprv
#
# flqzm
#
# hfuawnya
#
# os
#
# czbd
#
# jjnafejlb
#
# k
#
# fwipmsksj
#
# arxya
#
# pabe
#
# eb
#
# ibbkem
#
# ubr
#
# xq
#
# yvsmrkwv
#
# jtxgs
#
# r
#
# xxvfel
#
# a
#
# jrmghth
#
# gvsaalc
#
# yup
#
# hguqmhhja
#
# lcsdgcpxy
#
# gycitldu
#
# lzmwpu
#
# jndod
#
# vz
#
# s
#
# tux
#
# bcsthvndo
#
# ae
#
# qk
#
# stvjarqm
#
# ruebs
#
# f
#
# ylsnaud
#
# rjaqdwmhg
#
# vzaxpdyx
#
# cajz
#
# lxcwelb
#
# rozdszxu
#
# ccm
#
# kchxfbwow
#
# tokxnnohyx
#
# u
#
# glljiozxg
#
# vagjckdlf
#
# hisi
#
# ca
#
# d
#
# wjyq
#
# ohtvc
#
# hqkokbqhv
#
# tregjmvt
#
# dvylw
#
# eybm
#
# ...

# %%
data[0]
# Out:
# 'otvmhact\n'

# %%
tfile.read()
# Out:
# ''
